# %%
import numpy as np
from sklearn.datasets import make_blobs
from mlxtend.plotting import plot_decision_regions
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense

# %%
X , y = make_blobs(n_samples= 100, n_features=2, cluster_std=2.5, centers=2, random_state=44)

# %%
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from tensorflow.keras import Sequential

# %%
model = Sequential()

# %%
model.add(Input(shape= (2, )))
model.add(Dense(10, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# he_normal's formula for weights initialization is: np.sqrt(2/fan_in), fan_in is the total numbers of inputs.

# %% [markdown]
# he_uniform's formula for weights are initialization in the range of it's output : range = np.sqrt(6/fan_in) [- range, + range].

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=100, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 7s 703ms/step - loss: 3.4640 - accuracy: 0.5125 - val_loss: 4.8146 - val_accuracy: 0.4500
# Epoch 2/100
# 3/3 [==============================] - 0s 183ms/step - loss: 3.1265 - accuracy: 0.5125 - val_loss: 4.2891 - val_accuracy: 0.4500
# Epoch 3/100
# 3/3 [==============================] - 0s 123ms/step - loss: 2.7325 - accuracy: 0.5125 - val_loss: 3.7439 - val_accuracy: 0.4500
# Epoch 4/100
# 3/3 [==============================] - 1s 239ms/step - loss: 2.3507 - accuracy: 0.5125 - val_loss: 3.2448 - val_accuracy: 0.4000
# Epoch 5/100
# 3/3 [==============================] - 0s 214ms/step - loss: 2.0084 - accuracy: 0.5000 - val_loss: 2.8109 - val_accuracy: 0.4000
# Epoch 6/100
# 3/3 [==============================] - 0s 203ms/step - loss: 1.7889 - accuracy: 0.4875 - val_loss: 2.4594 - val_accuracy: 0.4000
# Epoch 7/100
# ...

# %%
plot_decision_regions(X, y, clf=model)
# Out:
# 9600/9600 [==============================] - 190s 20ms/step
# <Axes: >
