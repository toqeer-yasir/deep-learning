# %%
import numpy as np, pandas as pd
from sklearn.datasets import make_blobs

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
# Out:
# 2026-04-12 13:07:08.690166: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-12 13:07:08.861896: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-12 13:07:08.861981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-12 13:07:08.865491: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-12 13:07:08.888458: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
X, y = make_blobs(n_samples=300, n_features=2, centers=2, cluster_std=2.5, random_state=2)
X_train, y_train = X[:100, :], y[:100]

# %%
import matplotlib.pyplot as plt
plt.style.use('default')

# %%
plt.scatter(X_train[:, 0],X_train[:, 1], c=y_train)

# %%
model = Sequential()

# %%
model.add(Input(shape= (2,)))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# It gives linear line fitting results even with activation function 'tanh'.

# %%
model.summary()

# %%
model.get_weights()

# %%
initial_weights = model.get_weights()
initial_weights

# %%
print(type(initial_weights))
len(initial_weights)

# %%
initial_weights[0] = np.zeros_like(model.get_weights()[0])+0.5
initial_weights[1] = np.zeros_like(model.get_weights()[1])+0.5
initial_weights[2] = np.zeros_like(model.get_weights()[2])+0.5
initial_weights[3] = np.zeros_like(model.get_weights()[3])+0.5
model.set_weights(initial_weights)
model.get_weights()

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=44, validation_split=0.2, verbose=1)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train, clf = model)

# %% [markdown]
# # All the weights get updated with a same value for relu and tanh nothing non-linear gets captured in training. And all the nodes acts as a songle node.
